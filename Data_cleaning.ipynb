# %%
#importing module
import pandas as pd

# %%
#importing the dataset by reading the csv file
gross = "HighestGrossers.csv"
data = pd.read_csv(gross)

# %%
#displaying the first five rows of dataset 
data.head()
# Out:
#    YEAR                                MOVIE      GENRE MPAA RATING  \
# 0  1995                       Batman Forever      Drama       PG-13
# 1  1996                     Independence Day  Adventure       PG-13
# 2  1997                         Men in Black  Adventure       PG-13
# 3  1998                              Titanic  Adventure       PG-13
# 4  1999  Star Wars Ep. I: The Phantom Menace  Adventure          PG
#
#           DISTRIBUTOR TOTAL FOR YEAR TOTAL IN 2019 DOLLARS TICKETS SOLD
# 0        Warner Bros.   $184,031,112          $387,522,978  4,23,06,002
# 1    20th Century Fox   $306,169,255          $634,504,608  6,92,69,062
# 2       Sony Pictures   $250,650,052          $500,207,943  5,46,07,854
# 3  Paramount Pictures   $443,319,081          $865,842,808  9,45,24,324
# 4    20th Century Fox   $430,443,350          $776,153,749  8,47,32,942

# %%
#displaying last five rows of dataset
data.tail()
# Out:
#     YEAR                                      MOVIE   GENRE MPAA RATING  \
# 22  2017          Star Wars Ep. VIII: The Last Jedi  Action       PG-13
# 23  2018                              Black Panther  Action       PG-13
# 24  2019                          Avengers: Endgame     NaN       PG-13
# 25  2020                          Bad Boys For Life     NaN           R
# 26  2021  Shang-Chi and the Legend of the Ten Rings     NaN       PG-13
#
#       DISTRIBUTOR TOTAL FOR YEAR TOTAL IN 2019 DOLLARS TICKETS SOLD
# 22    Walt Disney   $517,218,368          $528,173,936  5,76,60,910
# 23    Walt Disney   $700,059,566          $703,901,821  7,68,45,177
# 24    Walt Disney   $858,373,000          $858,373,002  9,37,08,843
# 25  Sony Pictures   $204,417,855          $204,417,848  2,23,16,359
# 26    Walt Disney   $224,226,704          $224,226,704  2,44,78,897

# %%
data.memory_usage(deep=True)
# Out:
# Index                      72
# YEAR                      216
# MOVIE                    1811
# GENRE                    1361
# MPAA RATING              1323
# DISTRIBUTOR              1554
# TOTAL FOR YEAR           1539
# TOTAL IN 2019 DOLLARS    1539
# TICKETS SOLD             1512
# dtype: int64

# %%
data.columns
# Out:
# Index([u'YEAR', u'MOVIE', u'GENRE', u'MPAA RATING', u'DISTRIBUTOR',
#        u'TOTAL FOR YEAR', u'TOTAL IN 2019 DOLLARS', u'TICKETS SOLD'],
#       dtype='object')

# %%
data.loc[0:4, ['YEAR', 'MOVIE', 'TOTAL IN 2019 DOLLARS']]
# Out:
#    YEAR                                MOVIE TOTAL IN 2019 DOLLARS
# 0  1995                       Batman Forever          $387,522,978
# 1  1996                     Independence Day          $634,504,608
# 2  1997                         Men in Black          $500,207,943
# 3  1998                              Titanic          $865,842,808
# 4  1999  Star Wars Ep. I: The Phantom Menace          $776,153,749

# %%
data.sort_values(by='MOVIE', inplace=False)
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 24  2019                              Avengers: Endgame        NaN
# 25  2020                              Bad Boys For Life        NaN
# 0   1995                                 Batman Forever      Drama
# 23  2018                                  Black Panther     Action
# 21  2016                                   Finding Dory     Action
# 8   2003                                   Finding Nemo  Adventure
# 19  2014                        Guardians of the Galaxy  Adventure
# 16  2011  Harry Potter and the Deathly Hallows: Part II     Action
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 1   1996                               Independence Day  Adventure
# 18  2013                                     Iron Man 3  Adventure
# 2   1997                                   Men in Black  Adventure
# ...

# %%
data.describe()
# Out:
#               YEAR
# count    27.000000
# mean   2008.000000
# std       7.937254
# min    1995.000000
# 25%    2001.500000
# 50%    2008.000000
# 75%    2014.500000
# max    2021.000000

# %%
data['GENRE'].value_counts()
# Out:
# Adventure    14
# Action        9
# Drama         1
# Name: GENRE, dtype: int64

# %%
data.isnull()
# Out:
#      YEAR  MOVIE  GENRE  MPAA RATING  DISTRIBUTOR  TOTAL FOR YEAR  \
# 0   False  False  False        False        False           False
# 1   False  False  False        False        False           False
# 2   False  False  False        False        False           False
# 3   False  False  False        False        False           False
# 4   False  False  False        False        False           False
# 5   False  False  False        False        False           False
# 6   False  False  False        False        False           False
# 7   False  False  False        False        False           False
# 8   False  False  False        False        False           False
# 9   False  False  False        False        False           False
# 10  False  False  False        False        False           False
# 11  False  False  False        False        False           False
# 12  False  False  False        False        False           False
# ...

# %%
data.isna()
# Out:
#      YEAR  MOVIE  GENRE  MPAA RATING  DISTRIBUTOR  TOTAL FOR YEAR  \
# 0   False  False  False        False        False           False
# 1   False  False  False        False        False           False
# 2   False  False  False        False        False           False
# 3   False  False  False        False        False           False
# 4   False  False  False        False        False           False
# 5   False  False  False        False        False           False
# 6   False  False  False        False        False           False
# 7   False  False  False        False        False           False
# 8   False  False  False        False        False           False
# 9   False  False  False        False        False           False
# 10  False  False  False        False        False           False
# 11  False  False  False        False        False           False
# 12  False  False  False        False        False           False
# ...

# %%
data.isna().any()
# Out:
# YEAR                     False
# MOVIE                    False
# GENRE                     True
# MPAA RATING              False
# DISTRIBUTOR              False
# TOTAL FOR YEAR           False
# TOTAL IN 2019 DOLLARS    False
# TICKETS SOLD             False
# dtype: bool

# %%
data.isna().sum()
# Out:
# YEAR                     0
# MOVIE                    0
# GENRE                    3
# MPAA RATING              0
# DISTRIBUTOR              0
# TOTAL FOR YEAR           0
# TOTAL IN 2019 DOLLARS    0
# TICKETS SOLD             0
# dtype: int64

# %%
data.isna().any().sum()
# Out:
# 1

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# dtype: bool
